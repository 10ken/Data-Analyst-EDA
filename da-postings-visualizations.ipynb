# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/data-analyst-jobs/DataAnalyst.csv

# %%
data = pd.read_csv("/kaggle/input/data-analyst-jobs/DataAnalyst.csv")
data
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
data.info()
# 1 null in company name
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %%
data['Job Title'].nunique()
# Out:
# 1272

# %% [markdown]
# Of 2253 jobs, there are 1272 job titles.

# %%
top10_job_titles= data['Job Title'].value_counts().sort_values(ascending = False).head(10)
plt.pie(top10_job_titles, autopct='%.2f',pctdistance=1.3)
plt.title('Top 5 Most Popular Job Postings',fontweight ='bold')
plt.legend(list(dict(top10_job_titles).keys()), loc='upper right')
plt.show()

# %% [markdown]
# A data analyst role makes up more than 61% of job postings of the top 10 job titles.

# %%
data['Founded'].value_counts()
year_freq=data.groupby(['Founded']).size()[1:,]
year=data['Founded'].unique()
year = np.delete(pen, np.argwhere(pen==-1))
year = np.sort(year)
plt.plot(year,year_freq)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-adf5910be6dd> in <module>
#       2 year_freq=data.groupby(['Founded']).size()[1:,]
#       3 year=data['Founded'].unique()
# ----> 4 year = np.delete(pen, np.argwhere(pen==-1))
#       5 year = np.sort(year)
#       6 plt.plot(year,year_freq)
#
# NameError: name 'pen' is not defined

# %% [markdown]
# Companies founded within the last 20 years are hiring expontentially more than older companies.

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %% [markdown]
# From here on we will focus on exploring the data for Data Analyst roles.

# %%
df = data

# filter the jobs by city
for i in range(df.shape[0]): # remove state
    df['Location'].iloc[i] = df['Location'].iloc[i][:-3]

data_analyst = df['Job Title'] == 'Data Analyst'
da_indicies = df['Job Title'][data_analyst].index

da_data = df.iloc[da_indicies]

da_data
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       Unnamed: 0     Job Title             Salary Estimate  \
# 3              3  Data Analyst  $37K-$66K (Glassdoor est.)
# 5              5  Data Analyst  $37K-$66K (Glassdoor est.)
# 8              8  Data Analyst  $37K-$66K (Glassdoor est.)
# 10            10  Data Analyst  $37K-$66K (Glassdoor est.)
# 11            11  Data Analyst  $37K-$66K (Glassdoor est.)
# ...          ...           ...                         ...
# 2193        2193  Data Analyst  $49K-$91K (Glassdoor est.)
# 2197        2197  Data Analyst  $49K-$91K (Glassdoor est.)
# 2200        2200  Data Analyst  $49K-$91K (Glassdoor est.)
# ...

# %%
da_salary = np.sort(da_data['Salary Estimate'].unique())

da_salary
# Out:
# array(['$110K-$190K (Glassdoor est.)', '$24K-$48K (Glassdoor est.)',
#        '$26K-$47K (Glassdoor est.)', '$27K-$52K (Glassdoor est.)',
#        '$28K-$52K (Glassdoor est.)', '$29K-$38K (Glassdoor est.)',
#        '$30K-$53K (Glassdoor est.)', '$30K-$54K (Glassdoor est.)',
#        '$32K-$56K (Glassdoor est.)', '$34K-$61K (Glassdoor est.)',
#        '$35K-$67K (Glassdoor est.)', '$37K-$44K (Glassdoor est.)',
#        '$37K-$66K (Glassdoor est.)', '$37K-$68K (Glassdoor est.)',
#        '$37K-$70K (Glassdoor est.)', '$38K-$68K (Glassdoor est.)',
#        '$40K-$72K (Glassdoor est.)', '$41K-$78K (Glassdoor est.)',
#        '$41K-$86K (Glassdoor est.)', '$42K-$74K (Glassdoor est.)',
#        '$42K-$76K (Glassdoor est.)', '$43K-$69K (Glassdoor est.)',
#        '$43K-$76K (Glassdoor est.)', '$44K-$82K (Glassdoor est.)',
#        '$46K-$102K (Glassdoor est.)', '$46K-$87K (Glassdoor est.)',
#        '$47K-$76K (Glassdoor est.)', '$47K-$81K (Glassdoor est.)',
# ...

# %%
top5_da_salary = np.append(da_salary[-4:],'$110K-$190K (Glassdoor est.)')
top5_da_salary
# Out:
# array(['$89K-$151K (Glassdoor est.)', '$93K-$159K (Glassdoor est.)',
#        '$98K-$114K (Glassdoor est.)', '$99K-$178K (Glassdoor est.)',
#        '$110K-$190K (Glassdoor est.)'], dtype=object)

# %%
da_salary_dict = {}
for salary in top5_da_salary:
    true_false_cases = da_data['Salary Estimate'] == salary
    indicies = da_data['Salary Estimate'][true_false_cases].index
    
    da_salary_dict[salary] = indicies
da_salary_dict # dict of DAs at different salary estimates
# Out:
# {'$89K-$151K (Glassdoor est.)': Int64Index([1497, 1499, 1501, 1502, 1504, 1505, 1506, 1508, 1509, 1511, 1513,
#              1516, 1522, 1523],
#             dtype='int64'),
#  '$93K-$159K (Glassdoor est.)': Int64Index([1945, 1947, 1956, 1957, 1958, 1960, 1965, 1966, 1967], dtype='int64'),
#  '$98K-$114K (Glassdoor est.)': Int64Index([376], dtype='int64'),
#  '$99K-$178K (Glassdoor est.)': Int64Index([1916, 1920, 1922, 1926, 1927, 1930, 1932, 1934, 1935, 1936, 1938], dtype='int64'),
#  '$110K-$190K (Glassdoor est.)': Int64Index([1468, 1471, 1475, 1476, 1477, 1478, 1479, 1483, 1488, 1489, 1490,
#              1491, 1494, 1495, 1496],
#             dtype='int64')}

# %%
top5_sal_df = pd.DataFrame() 

for key in da_salary_dict.keys():
    top5_sal_df = top5_sal_df.append(df.iloc[da_salary_dict[key]])
top5_sal_df
# Out:
#       Unnamed: 0     Job Title               Salary Estimate  \
# 1497        1497  Data Analyst   $89K-$151K (Glassdoor est.)
# 1499        1499  Data Analyst   $89K-$151K (Glassdoor est.)
# 1501        1501  Data Analyst   $89K-$151K (Glassdoor est.)
# 1502        1502  Data Analyst   $89K-$151K (Glassdoor est.)
# 1504        1504  Data Analyst   $89K-$151K (Glassdoor est.)
# 1505        1505  Data Analyst   $89K-$151K (Glassdoor est.)
# 1506        1506  Data Analyst   $89K-$151K (Glassdoor est.)
# 1508        1508  Data Analyst   $89K-$151K (Glassdoor est.)
# 1509        1509  Data Analyst   $89K-$151K (Glassdoor est.)
# 1511        1511  Data Analyst   $89K-$151K (Glassdoor est.)
# 1513        1513  Data Analyst   $89K-$151K (Glassdoor est.)
# 1516        1516  Data Analyst   $89K-$151K (Glassdoor est.)
# 1522        1522  Data Analyst   $89K-$151K (Glassdoor est.)
# 1523        1523  Data Analyst   $89K-$151K (Glassdoor est.)
# ...

# %%
location_salary = pd.crosstab(top5_sal_df['Location'],top5_sal_df['Salary Estimate'])
location_salary.plot(kind='bar',width=2,figsize=(15,8))
plt.show()

top5_sal_df['Salary Estimate'].value_counts().plot(kind='barh',
                                                   color = ['black', 'green','blue','red','purple'])
plt.show()

# %% [markdown]
# The top 5 earners for a data analyst role lie in most like in California and New Jersey.

# %%
# word cloud for only data analyst positions

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

text = str(np.ravel(da_data['Job Description']))

wordcloud = WordCloud(max_font_size=50, max_words=10000, background_color="black").generate(text)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# word cloud for all positions

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

text = str(np.ravel(data['Job Description']))

wordcloud = WordCloud(max_font_size=50, max_words=10000, background_color="black").generate(text)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
